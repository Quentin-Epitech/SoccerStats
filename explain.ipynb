# %%
import pandas as pd 

read = pd.read_csv("top5-players.csv")

print(read.shape)
print(read.isna().sum())
# Out:
# (2852, 37)
# Rk             0
# Player         0
# Nation         3
# Pos            0
# Squad          0
# Comp           0
# Age            4
# Born           4
# MP             0
# Starts         0
# Min            0
# 90s            0
# Gls            0
# Ast            0
# G+A            0
# G-PK           0
# PK             0
# PKatt          0
# CrdY           0
# CrdR           0
# xG             1
# npxG           1
# xAG            1
# npxG+xAG       1
# PrgC           1
# PrgP           1
# PrgR           1
# Gls_90         0
# Ast_90         0
# G+A_90         0
# G-PK_90        0
# G+A-PK_90      0
# xG_90          1
# xAG_90         1
# xG+xAG_90      1
# npxG_90        1
# npxG+xAG_90    1
# dtype: int64

# %% [markdown]
# (2852, 37)
# Rk             0
# Player         0
# Nation         3
# Pos            0
# Squad          0
# Comp           0
# Age            4
# Born           4
# MP             0
# Starts         0
# Min            0
# 90s            0
# Gls            0
# Ast            0
# G+A            0
# G-PK           0
# PK             0
# PKatt          0
# CrdY           0
# CrdR           0
# xG             1
# npxG           1
# xAG            1
# npxG+xAG       1
# PrgC           1
# PrgP           1
# PrgR           1
# Gls_90         0
# Ast_90         0
# G+A_90         0
# G-PK_90        0
# G+A-PK_90      0
# xG_90          1
# xAG_90         1
# xG+xAG_90      1
# npxG_90        1
# npxG+xAG_90    1
# dtype: int64

# %% [markdown]
# Quelques données manquante sur certaines colonnes : 2 possibilités :
#
# Supprimer ces lignes
# Essayer de retrouver les données

# %%
df = pd.read_csv("top5-players.csv")

print("Valeurs manquantes :")
print(df.isna().sum())

df = df.fillna({
    col: "None" if df[col].dtype == "object" else 0 
    for col in df.columns})

print("\nValeurs manquantes après nettoyage :")
print(df.isna().sum())

df.to_csv("Clean.csv", index=False)
print("\nFichier nettoyé sauvegardé sous : Clean.csv")
# Out:
# Valeurs manquantes :
# Rk             0
# Player         0
# Nation         3
# Pos            0
# Squad          0
# Comp           0
# Age            4
# Born           4
# MP             0
# Starts         0
# Min            0
# 90s            0
# Gls            0
# Ast            0
# G+A            0
# G-PK           0
# PK             0
# PKatt          0
# CrdY           0
# CrdR           0
# xG             1
# npxG           1
# xAG            1
# npxG+xAG       1
# PrgC           1
# PrgP           1
# PrgR           1
# Gls_90         0
# Ast_90         0
# G+A_90         0
# G-PK_90        0
# G+A-PK_90      0
# xG_90          1
# xAG_90         1
# xG+xAG_90      1
# npxG_90        1
# npxG+xAG_90    1
# dtype: int64
#
# Valeurs manquantes après nettoyage :
# Rk             0
# Player         0
# Nation         0
# Pos            0
# Squad          0
# Comp           0
# Age            0
# Born           0
# MP             0
# Starts         0
# Min            0
# 90s            0
# Gls            0
# Ast            0
# G+A            0
# G-PK           0
# PK             0
# PKatt          0
# CrdY           0
# CrdR           0
# xG             0
# npxG           0
# xAG            0
# npxG+xAG       0
# PrgC           0
# PrgP           0
# PrgR           0
# Gls_90         0
# Ast_90         0
# G+A_90         0
# G-PK_90        0
# G+A-PK_90      0
# xG_90          0
# xAG_90         0
# xG+xAG_90      0
# npxG_90        0
# npxG+xAG_90    0
# dtype: int64
#
# Fichier nettoyé sauvegardé sous : Clean.csv

# %%
# Out:
# (2852, 37)
# Rk             0
# Player         0
# Nation         3
# Pos            0
# Squad          0
# Comp           0
# Age            0
# Born           0
# MP             0
# Starts         0
# Min            0
# 90s            0
# Gls            0
# Ast            0
# G+A            0
# G-PK           0
# PK             0
# PKatt          0
# CrdY           0
# CrdR           0
# xG             0
# npxG           0
# xAG            0
# npxG+xAG       0
# PrgC           0
# PrgP           0
# PrgR           0
# Gls_90         0
# Ast_90         0
# G+A_90         0
# G-PK_90        0
# G+A-PK_90      0
# xG_90          0
# xAG_90         0
# xG+xAG_90      0
# npxG_90        0
# npxG+xAG_90    0
# dtype: int64

# %% [markdown]
# Remplae cellule par None
